# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_community.utilities import GoogleSerperAPIWrapper
from langchain_groq import ChatGroq
from langchain.agents import create_agent

# %%
llm = ChatGroq(model="openai/gpt-oss-20b")
search = GoogleSerperAPIWrapper()

# %%
agent = create_agent(
    model=llm,
    tools=[search.run],
    system_prompt="You are a agents and can search any question on google"
)

# %%
question="What is the address of UCD  Dublin"

# %%
response= agent.invoke({"messages":[{"role":"user", "content":question}]})

# %%
print(response["messages"][-1].content)
# Out:
# **University College Dublin (UCD) – Main Campus (Belfield)**
# **Address:**
# University College Dublin
# Belfield, Dublin 4
# Ireland
# Eircode: **D04 V1W8**
#
# The main campus (Belfield) is located on the north side of Dublin, just south of the River Liffey, and is the primary site for most undergraduate and postgraduate study, research, and administrative services.
#
# If you need to visit a specific department or office, you can usually find the exact building and room number on the UCD website or by contacting the relevant faculty.
